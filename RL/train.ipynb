# %%
# !git clone https://github.com/TianTianHang/Pyleste
# !cd Pyleste
# Out:
# Cloning into 'Pyleste'...
# remote: Enumerating objects: 283, done.
# remote: Counting objects: 100% (56/56), done.
# remote: Compressing objects: 100% (41/41), done.
# remote: Total 283 (delta 21), reused 38 (delta 11), pack-reused 227 (from 1)
# Receiving objects: 100% (283/283), 99.77 KiB | 1.56 MiB/s, done.
# Resolving deltas: 100% (137/137), done.

# %%
import os
os.chdir('/content/Pyleste')
# %run ./RL/train.py
# Out:
# Celeste DQN Training
# 1. Train agent
# 2. Test agent
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /content/Pyleste/RL/train.py in <module>
#     150     if choice == "1":
#     151         episodes = int(input("Enter number of episodes (default 1000): ") or "1000")
# --> 152         train_agent(episodes)
#     153     elif choice == "2":
#     154         episodes = int(input("Enter number of test episodes (default 5): ") or "5")
#
# /content/Pyleste/RL/train.py in train_agent(episodes)
#      15     n_actions = env.action_space
#      16
# ---> 17     agent = DQNAgent(
#      18         state_shape=state_shape,
#      19         n_actions=n_actions,
#
# /content/Pyleste/RL/dqn_agent.py in __init__(self, state_shape, n_actions, lr, gamma, epsilon, epsilon_decay, epsilon_min, memory_size)
#      81
#      82         # Neural networks
# ...
