# %%
# !git clone https://github.com/TianTianHang/Pyleste
# !cd Pyleste
# Out:
# fatal: destination path 'Pyleste' already exists and is not an empty directory.

# %%
import os
os.chdir('/content/Pyleste')
# !git pull
# %run ./RL/train.py
# Out:
# New best model saved with score: 3085.00
# Episode: 0, Score: 3085.00, Avg Score: 3085.00, Epsilon: 0.129, Steps: 441
